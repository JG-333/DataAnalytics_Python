# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('Marks.csv')
df.head()
# Out:
#   Course  Cyclic Test-1 (out of 40)  Cyclic Test-2 (out of 40)  \
# 0     DM                         40                         40
# 1     AP                         40                         38
# 2     EC                         37                         40
# 3    EDA                         39                         39
# 4    EAI                         39                         40
#
#    Cyclic Test-3 (out of 40)  Cyclic Test-4 (out of 40)
# 0                         39                         40
# 1                         40                         40
# 2                         39                         40
# 3                         40                         40
# 4                         40                         40

# %%
plots = sns.barplot(x="Course", y="Cyclic Test-1 (out of 40)", data=df, width = 0.8)
plt.title("Cyclic Test-1 Result")
plt.xlabel("Courses", size=10)
plt.ylabel("Marks", size=10)
# Out:
# Text(0, 0.5, 'Marks')

# %%
plots = sns.barplot(x="Course", y="Cyclic Test-2 (out of 40)", data=df, width = 0.8)
plt.title("Cyclic Test-2 Result")
plt.xlabel("Courses", size=10)
plt.ylabel("Marks", size=10)
# Out:
# Text(0, 0.5, 'Marks')

# %%
plots = sns.barplot(x="Course", y="Cyclic Test-3 (out of 40)", data=df, width = 0.8)
plt.title("Cyclic Test-3 Result")
plt.xlabel("Courses", size=10)
plt.ylabel("Marks", size=10)
# Out:
# Text(0, 0.5, 'Marks')

# %%
plots = sns.barplot(x="Course", y="Cyclic Test-4 (out of 40)", data=df, width = 0.8)
plt.title("Cyclic Test-4 Result")
plt.xlabel("Courses", size=10)
plt.ylabel("Marks", size=10)
# Out:
# Text(0, 0.5, 'Marks')
